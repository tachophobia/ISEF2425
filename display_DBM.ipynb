# %%
from DBM import DBM

# %%
dbm = DBM(eta=3, dim=100)
dbm.add_line_of_charge((dbm.dim+5, 0), (dbm.dim+5, 2*dbm.dim))
dbm.add_circle_of_charge((dbm.dim, dbm.dim), dbm.dim/4)
dbm.simulate(steps=1000)
dbm.show(show_environment=True)
